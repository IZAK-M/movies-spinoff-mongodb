# %% [markdown]
# ### Création d'une DB_test via l'invites de commandes

# %% [markdown]
# ![DB_test_cmd.PNG](attachment:f85d51c8-f2f3-4361-a1c7-18dea753fd98.PNG)

# %% [markdown]
# ### Visualisation DB_test sur Mongo Compass et rajout de collection_2

# %% [markdown]
# ![Db_test_compass.PNG](attachment:48b978d7-e4bd-411d-bad3-4b9048c0e10d.PNG)
